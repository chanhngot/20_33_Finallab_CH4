# %%
# a. Thống kê tần suất từ xuất hiện trong văn bản;
# b. Trực quan hóa bằng đồ thị và word cloud;
# Cách làm: gộp các file txt vừa tiền xử lí vào 1 file all-in-one.txt trước
import nltk
import re
import os
nltk.download('stopwords')
nltk.download('punkt')
from nltk.probability import FreqDist
from nltk.corpus import stopwords
#Read file text
with open('D:\python\FinalLab_Ch4\gop.txt', 'r', encoding='utf-8') as file:
    text = file.read()
text_pre=nltk.word_tokenize(text) # Tokenizing
print("Number of words: ",len(text_pre))
# Compute the frequency of all words
frequency_dist = FreqDist(word.lower() for word in text_pre)
## show only th top 50 results
print(frequency_dist.most_common(50))
## Consider words with length greater than 3 and plot
large_words = dict([(k,v) for k,v in frequency_dist.items() if len(k)>3])
frequency_dist = nltk.FreqDist(large_words)
frequency_dist.plot(50,cumulative=False)
from wordcloud import WordCloud
wcloud = WordCloud().generate_from_frequencies(frequency_dist)
#plotting the wordcloud
import matplotlib.pyplot as plt
plt.imshow(wcloud, interpolation="bilinear")
plt.axis("off")
plt.show()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# Number of words:  10865
# [('.', 812), ('quán', 214), ('k', 172), ('đi', 151), ('ko', 136), ('ngon', 116), ('món', 111), ('gọi', 111), ('nhân_viên', 103), ('uống', 100), ('phục_vụ', 91), ('bàn', 72), ('mấy', 70), ('n', 70), ('bánh', 69), ('trà', 66), ('hơi', 65), ('i', 62), ('chỗ', 57), ('đồ_ăn', 56), ('...', 56), ('ng', 53), ('tiền', 52), ('giá', 50), ('thử', 48), ('đông', 48), ('lắm', 47), ('xong', 46), ('t', 45), ('đc', 44), ('sữa', 44), ('ly', 41), ('chờ', 40), ('vị', 39), ('kêu', 38), ('c', 37), ('nh', 36), ('đợi', 35), ('xe', 34), ('chạy', 33), ('đồ', 33), ('bò', 33), ('kiểu', 32), ('order', 32), ('thi', 32), ('rẻ', 31), ('chụp', 30), ('h', 30), ('mua', 29), ('bình_thường', 29)]

# %%
with open("D:\python\FinalLab_Ch4\gop.txt", "r", encoding="utf-8") as f:
    data = f.read()
data = data.split("\n")
while "" in data:
    data.remove("")
    
from sklearn.feature_extraction.text import CountVectorizer 

# Khởi tạo đối tượng CountVectorizer
# Tham số ngram_range=(1,2) cho biết chúng ta muốn sử dụng N-grams từ 1 đến 2.
vectorizer = CountVectorizer(ngram_range=(1,2))

# Biểu diễn vector đặc trưng cho các câu
features = vectorizer.fit_transform(data)

# In ra các feature vector tương ứng với các câu
# Mỗi hàng trong ma trận tương ứng với một câu và mỗi cột tương ứng với một N-gram trong tất cả các câu. Giá trị của mỗi phần tử trong ma trận là số lần xuất hiện của N-gram đó trong câu tương ứng.
arr=features.toarray()

print("Vocabulary N-gram:")
for i in range(len(data)):
    # print(sorted(vectorizer.fit(["The quick brown fox jumps over the lazy dog and"]).vocabulary_))
    print(vectorizer.fit([data[i]]).vocabulary_)
    print(arr[0])
# Out:
# Vocabulary N-gram:
# {'mua': 4659, 'bingsu': 137, 'thập_cẩm': 7969, 'đợi': 10720, 'nv': 6028, 'tl': 8284, 'nhg': 5649, 'bảo': 608, 'chờ': 1420, 'tụi': 8981, 'lm': 4067, 'liền': 4055, 'mình': 4790, 'ngon': 5332, 'thử': 8095, 'thiết_nghĩ': 7662, 'quán': 6727, 'xem_lại': 9533, 'pv': 6661, 'nc': 5223, 'vs': 9180, 'ta': 7541, 'quẩy': 6950, 'bomb': 184, 'bombvuvuzela': 187, 'beer': 107, 'club': 1527, 'hệ_thống': 3301, 'gogi_house': 2649, 'daruma': 2074, 'kichi': 3643, 'giá': 2524, 'vat': 9118, 'thanh_toán': 7590, 'hằng': 3271, 'đc': 9873, 'thức_ăn': 8071, 'zui': 9782, 'smiling_face_with_smiling_eyes': 7281, 'smiling_face_with_smiling_eyesngồi': 7286, 'thư_giãn': 7897, 'ok': 6303, 'ổn': 10878, 'mấy': 4972, 'món': 4811, 'nguyên_liệu': 5462, 'hok': 2935, 'bik': 129, 'chỗ': 1369, 'vô': 9265, 'cơ_mà': 1828, 'gọi': 2749, 'ko': 3743, 'hàng': 3019, 'face_with_tears_of_joy': 2361, 'face_with_tears_of_joycháo': 2370, 'bồ_câu': 730, 'hình': 3059, 'chụp': 1474, 'nguyên': 5454, 'hoài': 2965, 'phao_câu': 6412, 'đầu': 10406, 'chạy': 1169, 'nhà_bếp': 5702, 'trả_lời': 8486, 'cháo': 1059, 'tính_toán': 8656, 'thịt': 8033, 'cố_định': 1982, 'gram': 2661, 'grinning_face_with_sweat': 2665, 'grinning_face_with_sweatps': 2668, 'rủ': 7179, 'đứa': 10752, 'đi': 9948, 'tặng': 8878, 'ly': 4118, 'biaaaaaaaaaaaaaa': 127, 'mí': 4805, 'beer_mug': 109, 'tổng_cộng': 8964, 'no': 5989, 'cá_lóc': 1686, 'nướng': 6179, 'to': 8286, 'thiệt': 7670, 'kèm': 3856, 'rau_sống': 7009, 'bún': 538, 'bánh_tráng': 377, 'đồ': 10605, 'ah': 9, 'bắp': 674, 'giò': 2579, 'gói': 2713, 'nữađồ_ăn': 6294, 'rẻ': 7118, 'thích_hợp': 7830, 'ăn_uống': 9844, 'tuần': 8594, 'gia_đìnhtuy_nhiên': 2502, 'nước_chấm': 6151, 'mắm_nêm': 5052, 'mùi': 4910, 'gừng': 2833, 'kỳ': 3978, 'cá': 1659, 'nguội': 5468, 'hâm_nóng': 3046, 'nhân_viên': 5748, 'phục_vụ': 6562, 'tận_tình': 8866, 'đồ_ăn': 10622, 'cơm': 1834, 'bò': 487, 'mì': 4782, 'soba': 7297, 'xào': 9659, 'lắm': 4364, 'bàn': 242, 'bình_thường': 450, 'dọn': 2303, 'ai_ngờ': 16, 'xong': 9575, 'tốp': 8956, 'vô_hình': 9291, 'lơ': 4268, 'cười': 1869, 'nửa': 6268, 'miệng': 4626, 'có_lẽ': 1725, 'ưu_tiên': 10791, 'đông': 10265, 'lợi_nhuận': 4465, 'xem_thường': 9540, 'phong_cách': 6436, 'làm_việc': 4170, 'tệ_hại': 8920, 'đón_tiếp': 10236, 'kiểu': 3701, 'sổ_đen': 7465, 'hôm_nay': 3117, 'aeon': 0, 'ghé': 2451, 'hơi': 3155, 'không_gian': 3573, 'tối': 8935, 'order': 6335, 'nhét': 5827, 'kẽ': 3952, 'xi': 9544, 'nhê': 5829, 'lẩu': 4347, 'sả': 7417, 'tạm': 8792, 'mắc': 5030, 'hình_ảnh': 3085, 'menu': 4550, 'tính_chất': 8654, 'minh_hoạ': 4591, 'phục_vụ_bàn': 6624, 'gà': 2670, 'trứng': 8546, 'must': 4688, 'try': 8394, 'kiu': 3680, 'thất_vọng': 7945, 'vô_cùng': 9288, 'cục': 2027, 'tỏi': 8924, 'dĩa': 2208, 'gỏi': 2827, 'lát': 4189, 'rau': 6987, 'nói_chung': 6075, 'cho_biết': 970, 'ý_định': 9836, 'quá_đỗi': 6721, 'miếng': 4607, 'xôi': 9707, 'sạn': 7415, 'xứng_đáng': 9748, 'giá_cả': 2559, 'nhiệt_tình': 5670, 'vui_vẻ': 9213, 'hào_phóng': 3033, 'yêu_cầu': 9773, 'thắc_mắc': 7987, 'lịch_sự': 4428, 'buffet': 208, 'tự_phục_vụ': 9008, 'ngại': 5532, 'sẵn_lòng': 7438, 'đùm': 10312, 'hề': 3291, 'phàn_nàn': 6456, 'hợp': 3364, 'biêt': 147, 'thưởng_thức': 7920, 'chúc': 1132, 'bữa': 782, 'thoải_mái': 7697, 'hongkong': 2947, 'town': 8310, 'hôm_qua': 3130, 'công_ty': 1785, 'quảng_cáo': 6933, 'thành': 7733, 'chủ': 1492, 'nụ_cười': 6262, 'đầu_tiên': 10429, 'đem': 9916, 'toàn': 8312, 'thị': 8031, 'vụn': 9433, 'tôm': 8682, 'tươi': 8739, 'cón': 1771, 'tệ': 8896, 'bao_gồm': 79, 'sấm': 7420, 'thỉ': 8026, 'cũ': 1810, 'đổi': 10691, 'hoá_đơn': 2975, 'đỏ': 10589, 'ngày_sau': 5482, 'túm': 8714, 'làm_ăn': 4175, 'cẩu_thả': 1950, 'gian_dối': 2511, 'trừ': 8562, 'xắt': 9726, 'mỏng': 5138, 'rau_muống': 7003, 'dai_nhách': 2066, 'cải': 1883, 'thảo': 7939, 'úng': 9830, 'cộng': 2010, 'comment': 1588, 'khuyên': 3496, 'lót_dạ': 4235, 'thui': 7714, 'nhiu': 5656, 'đói': 10224, 'king': 3655, 'kệ': 3971, 'nhưng_mà': 5884, 'tráng_miệng': 8433, 'kem': 3411, 'siêu': 7270, 'rau_câu': 7001, 'chè': 1080, 'về': 9364, 'thì_phải': 7817, 'dở': 2319, 'hq':  ...
# [2 1 1 ... 1 1 1]

# %%
with open("D:\python\FinalLab_Ch4\gop.txt", "r", encoding="utf-8") as f:
    data = f.read()
data = data.split("\n")
while "" in data:
    data.remove("")

from sklearn.feature_extraction.text import CountVectorizer

# Xay dung vector BOW
vect = CountVectorizer()
X = vect.fit_transform(data)

# Xay dung tu dien
dictionary=list(vect.get_feature_names_out())
print("Words in dictionary: ", dictionary)
print("Vector Bag-of-Word: \n", X.toarray())
# Out:
# Words in dictionary:  ['aeon', 'aeon_mall', 'aeon_mall_bình_dương', 'aeonmall', 'ah', 'ai', 'ai_lại', 'ai_ngờ', 'ai_nấy', 'alaska', 'an', 'an_ninh', 'an_tâmchỉ', 'and', 'anh_chị', 'anh_ấy', 'ashima', 'atiso', 'ba_chẽ', 'ba_chỉ', 'ba_rọi', 'ba_động', 'back', 'ban', 'ban_đầu', 'banh', 'bao', 'bao_bì', 'bao_giờ', 'bao_gồm', 'bao_lâu', 'bao_nhiêu', 'bay', 'bbq', 'be', 'beaming_face_with_smiling_eyes', 'beefsteak', 'beer', 'beer_mug', 'bgiờ', 'bh', 'bi', 'bia', 'biaaaaaaaaaaaaaa', 'bik', 'bill', 'bingsu', 'biét', 'biê', 'biên', 'biên_giới', 'biêt', 'biến', 'biết_bao_nhiêu', 'biết_mấy', 'biển', 'biển_hiệu', 'biểu', 'biệt', 'bkg', 'blended', 'bmi', 'bn', 'bnhiu', 'bo', 'bobapop', 'bomb', 'bombvuvuzela', 'bong', 'bong_bóng', 'box', 'bt', 'bu', 'bua', 'buffet', 'burger', 'bus', 'buôn_bán', 'buồn', 'buồn_cười', 'buổi_sáng', 'buổi_trưa', 'bà_cụ', 'bài_bản', 'bài_trí', 'bàn', 'bàn_là', 'bàn_tính', 'bànkhói', 'bào', 'bàu_cát', 'bám', 'bánh', 'bánh_mì', 'bánh_quế', 'bánh_tráng', 'báo', 'báo_giá', 'bát_nháo', 'bây_giờ', 'bãi', 'bãi_biển', 'bão_bùng', 'bèo_nhèo', 'bé', 'bé_tẹo', 'béo', 'béo_béo', 'bê', 'bê_tông', 'bên_bị', 'bên_cạnh', 'bình', 'bình_ba', 'bình_dân', 'bình_dương', 'bình_luận', 'bình_thường', 'bình_thườngthức', 'bí_bách', 'bía', 'bít', 'bò', 'bó_tay', 'bóng_tối', 'bôi_bác', 'bông_gòn', 'bõ', 'bù', 'bùi_thị_tự_nhiên', 'bùng', 'bún', 'bă', 'băm', 'bơ', 'bưa', 'bưng', 'bạc', 'bạc_hà', 'bạc_phơ', 'bạch_tuộc', 'bạn', 'bạn_bè', 'bảg', 'bản_chất', 'bản_thân', 'bảng', 'bảng_hiệu', 'bảo', 'bảo_quản', 'bảo_vệ', 'bấm', 'bất', 'bất_kỳ', 'bất_lịch_sựcó', 'bất_tiện', 'bấy_nhiêu', 'bần', 'bẩn', 'bậc', 'bận_rộn', 'bật', 'bậy', 'bắp', 'bắt', 'bắt_mắt', 'bắt_đầu_từ', 'bắt_đền', 'bằng_được', 'bếp', 'bếp_núc', 'bệnh', 'bị_thương', 'bọ', 'bọn', 'bỏ_dởnói_chung', 'bỏ_qua', 'bỏng', 'bố_trí', 'bốc', 'bồ_câu', 'bồn', 'bồng', 'bổn', 'bộ_đồ', 'bộ_đội', 'bộn_bề', 'bột', 'bớt', 'bờ', 'bở', 'bỡ', 'bục', 'bụi', 'bụng', 'bức_xúc', 'bửa', 'bữa', 'bực', 'bực_bội', 'bực_mình', 'ca', 'caesar', 'cafe', 'cafe_hazenut', 'cafe_latte', 'cai', 'caia', 'cam', 'campuchia', 'cancel', 'candy', 'canh', 'canh_soup_miso_lạnh_ngắt_luôn', 'cao_sucơm', 'cao_vút', 'card', 'cay', 'cay_cay', 'cf', 'cgv', 'ch', 'chago', 'chai', 'champagne', 'chanh', 'chanh_chua', 'chap', 'chat', 'che', 'che_khuất', 'check', 'cheese', 'chgo', 'chi', 'chi_chít', 'chi_nhánh', 'chi_phí', 'chi_tiết', 'chiên', 'chiếu', 'chiều', 'chiều_hôm', 'chjay', 'cho_biết', 'cho_rồi', 'choco', 'choco_vanila', 'chocolate', 'choẹt', 'chs', 'chu', 'chu_đáo', 'chua', 'chua_chua', 'chug', 'chui', 'chup', 'chut', 'chuyên', 'chuyên_nghiệp', 'chuyến', 'chuẩn_bị', 'chuốc', 'chào', 'chán', 'chán_ghét', 'cháo', 'chát', 'cháy', 'châ', 'châm', 'chân', 'chã', 'chè', 'chém', 'chén', 'chê', 'chí', 'chín', 'chính_xác', 'chó', 'chùa', 'chúc', 'chúng_nó', 'chúng_tôi', 'chút', 'chă', 'chăm', 'chăm_sóc', 'chư', 'chương_trình', 'chướng', 'chạy', 'chạy_tới_chạy_lui', 'chả', 'chảng', 'chảnh', 'chảo', 'chảy', 'chấm', 'chấm_dứt', 'chấp_nhận', 'chất', 'chất_lượng', 'chất_lượngwifi', 'chần_chừ', 'chậm', 'chậm_chạp', 'chập', 'chật', 'chật_chội', 'chật_chộibeer', 'chật_hẹp', 'chậu', 'chắc', 'chắc_chắn', 'chắc_ăn', 'chắn', 'chắp_vá', 'chẳng', 'chặn', 'chặt', 'chẻ', 'chế_biến', 'chế_độ', 'chết', 'chỉ_dẫn', 'chỉnh', 'chị_em', 'chọt', 'chốc', 'chồng', 'chổ', 'chổng', 'chỗ', 'chờ', 'chờ_đợi', 'chở', 'chợ', 'chục', 'chụp', 'chủ', 'chủ_nhật', 'chủ_yếu', 'chừa', 'chừng', 'chửi', 'chữ', 'ciu', 'club', 'cmnd', 'cmt', 'cn', 'co', 'coa', 'coca', 'cocacola', 'coconut', 'coffee', 'coi', 'coi_thường', 'cold', 'combo', 'come', 'comment', 'con_nghiện', 'con_người', 'con_nít', 'confused_face', 'cookie', 'cow', 'crepe', 'crush', 'crying_face', 'cu', 'cua', 'cung', 'cuoi', 'cute', 'cuô', 'cuả', 'cuối', 'cuối_cùng', 'cuộn', 'cx', 'cà', 'cà_chua', 'cà_phê', 'cà_tím', 'càng_ngày_càng', 'cá', 'cá_chép', 'cá_hồi', 'cá_lóc', 'cá_ngừ', 'cá_trích', 'các', 'cái', 'cáu', 'câ', 'cân', 'cân_nhắc', 'câu', 'câu_khách', 'cây_cỏ', 'cã', 'cãi', 'còn', 'có_khi', 'có_lẽ', 'có_mang', 'có ...
# Vector Bag-of-Word:
#  [[2 1 1 ... 1 1 1]]
